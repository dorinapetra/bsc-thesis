# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns
sns.set_palette(sns.color_palette('Set2')[::2])
sns.set_context('paper', font_scale=1.5)

heatmap_cmap = 'GnBu'

import scipy
from scipy.stats import ttest_rel, beta, ttest_ind
from sklearn.cluster import KMeans
import numpy as np
import os
import yaml
import shutil
from collections import OrderedDict

from utils import quick_load_experiments_tsv, get_significance_by_column, add_probing_location_better_column
from common import lang2code, code2lang, lang2family, family2langs

figure_dir = "fig/tokenization"
os.makedirs("fig", exist_ok=True)
os.makedirs(figure_dir, exist_ok=True)

np.random.seed(2)

# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# # Load data

# %%
def get_model(row):
    model = "mBERT"
    if row["randomize_embedding_weights"]:
        model = model + "-rand"
        if row["use_character_tokenization"] == "full":
            model = model + "-char"
        else:
            model = model + "-subw"
    else:
        if row["use_character_tokenization"] == "full":
            model = model + "-char"
        else:
            return np.nan
    return model



exps = pd.read_table("../dataframes/experiments.tsv", sep="\t", quoting=3)

exps["task"] = exps["feature"]
exps["perturbation"] = exps.apply(get_model, axis=1)

exps["model"] = "mBERT"

exps = exps[["model", "language", "task", "dev_acc", "test_acc", "perturbation"]]

exps['tag'] = exps['task'].apply(lambda t: t.split("_")[0])
exps['pos'] = exps['task'].apply(lambda t: t.split("_")[1])
exps['full_task'] = exps['language'] + ' ' + exps['task']
exps['family'] = exps['language'].apply(lambda l: lang2family[l])

exps["probing_location"] = "last"
exps["probing_location_better"] = True

# %%
exps.head()
print(exps.model.unique())
print(exps.perturbation.unique())
# Out:
# ['mBERT']
# ['mBERT-rand-char' 'mBERT-char' 'mBERT-rand-subw' nan]

# %% [markdown]
# ## Load fertility and majority baseline

# %%
fertility = pd.read_table("../dataframes/task_fertility.tsv")
fertility.shape
# Out:
# (319, 14)

# %%
old_len = len(exps)

exps = exps.merge(fertility, on=['language', 'task'], how='inner')

if old_len != len(exps):
    raise ValueError(f"Merging with fertility dataframe changed the number of rows: {old_len} --> {len(exps)}")

# %% [markdown]
# # Perturbations

# %%
data_perturbations = ['TARG', 'L$_2$', 'R$_2$', 'B$_2$', 'permute']
model_perturbations = [
    'mBERT-char',
    'mBERT-rand-subw', 
    'mBERT-rand-char',
    #'mBERT-emb',
    #'mBERT-nocontext',
    #'prev',
    #'next'
]
baseline_models = ['chLSTM', 'chLSTM-rand', 'swLSTM', 'fastText']

# %% [markdown]
# # Model perturbations

# %%
models = ['mBERT'] + model_perturbations #+ baseline_models

baselines = exps[
    ((exps.model.isin(baseline_models)) & (exps.perturbation.isnull())) |
    ((exps.model=='mBERT') & (exps.perturbation.isnull())) |
    ((exps.model=='mBERT') & (exps.perturbation.isin(model_perturbations)))
]
baselines = baselines[baselines['probing_location_better']==True].copy()
baselines
# Out:
#        model language         task  dev_acc  test_acc     perturbation  \
# 0      mBERT  Catalan  number_verb    0.950     0.975  mBERT-rand-char
# 1      mBERT  Catalan  number_verb    0.995     1.000       mBERT-char
# 2      mBERT  Catalan  number_verb    0.950     0.895  mBERT-rand-subw
# 3      mBERT  Catalan  number_verb    1.000     0.990              NaN
# 4      mBERT  Catalan  number_verb    0.525     0.520  mBERT-rand-char
# ...      ...      ...          ...      ...       ...              ...
# 12755  mBERT    Greek  number_noun    0.990     0.980              NaN
# 12756  mBERT    Greek  number_noun    0.485     0.500  mBERT-rand-char
# 12757  mBERT    Greek  number_noun    0.960     0.950       mBERT-char
# 12758  mBERT    Greek  number_noun    0.500     0.520  mBERT-rand-subw
# 12759  mBERT    Greek  number_noun    0.990     0.995              NaN
#
#           tag   pos            full_task   family  ... majority_baseline  \
# 0      number  verb  Catalan number_verb  Romance  ...              50.0
# 1      number  verb  Catalan number_verb  Romance  ...              50.0
# 2      number  verb  Catalan number_verb  Romance  ...              50.0
# 3      number  verb  Catalan number_verb  Romance  ...              50.0
# 4      number  verb  Catalan number_verb  Romance  ...              50.0
# ...       ...   ...                  ...      ...  ...               ...
# 12755  number  noun    Greek number_noun    Greek  ...              50.0
# 12756  number  noun    Greek number_noun    Greek  ...              50.0
# 12757  number  noun    Greek number_noun    Greek  ...              50.0
# 12758  number  noun    Greek number_noun    Greek  ...              50.0
# 12759  number  noun    Greek number_noun    Greek  ...              50.0
#
#        sentence_char_len  sentence_char_per_subword  sentence_fertility  \
# 0             115.370417                   3.048666            1.440921
# 1             115.370417                   3.048666            1.440921
# 2             115.370417                   3.048666            1.440921
# 3             115.370417                   3.048666            1.440921
# 4             115.370417                   3.048666            1.440921
# ...                  ...                        ...                 ...
# 12755         135.269583                   2.076860            2.551967
# 12756         135.269583                   2.076860            2.551967
# 12757         135.269583                   2.076860            2.551967
# 12758         135.269583                   2.076860            2.551967
# 12759         135.269583                   2.076860            2.551967
#
#        sentence_subword_len  sentence_word_len  target_char_len  \
# 0                 37.821250          26.379167         8.084167
# 1                 37.821250          26.379167         8.084167
# 2                 37.821250          26.379167         8.084167
# 3                 37.821250          26.379167         8.084167
# 4                 37.821250          26.379167         8.084167
# ...                     ...                ...              ...
# 12755             65.251667          25.829583         8.522083
# 12756             65.251667          25.829583         8.522083
# 12757             65.251667          25.829583         8.522083
# 12758             65.251667          25.829583         8.522083
# 12759             65.251667          25.829583         8.522083
#
#        target_char_per_subword  target_fertility  target_subw_entropy
# 0                     3.365326            2.5525             8.780692
# 1                     3.365326            2.5525             8.780692
# 2                     3.365326            2.5525             8.780692
# 3                     3.365326            2.5525             8.780692
# 4                     3.365326            2.5525             8.780692
# ...                        ...               ...                  ...
# 12755                 1.994425            4.6200             5.277512
# 12756                 1.994425            4.6200             5.277512
# 12757                 1.994425            4.6200             5.277512
# 12758                 1.994425            4.6200             5.277512
# 12759                 1.994425            4.6200             5.277512
#
# [12760 rows x 24 columns]

# %%
baselines['model2'] = None

baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isnull()), 'model2'] = 'mBERT'
baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isin(model_perturbations)), 'model2'] = \
    baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isin(model_perturbations)), 'perturbation']
baselines.loc[((baselines.model.isin(baseline_models)) & (baselines.perturbation.isnull())), 'model2'] = \
    baselines.loc[((baselines.model.isin(baseline_models)) & (baselines.perturbation.isnull())), 'model']

# %%
baselines['model'] = baselines['model2']
baselines.head()
# Out:
#              model language         task  dev_acc  test_acc     perturbation  \
# 0  mBERT-rand-char  Catalan  number_verb    0.950     0.975  mBERT-rand-char
# 1       mBERT-char  Catalan  number_verb    0.995     1.000       mBERT-char
# 2  mBERT-rand-subw  Catalan  number_verb    0.950     0.895  mBERT-rand-subw
# 3            mBERT  Catalan  number_verb    1.000     0.990              NaN
# 4  mBERT-rand-char  Catalan  number_verb    0.525     0.520  mBERT-rand-char
#
#       tag   pos            full_task   family  ... sentence_char_len  \
# 0  number  verb  Catalan number_verb  Romance  ...        115.370417
# 1  number  verb  Catalan number_verb  Romance  ...        115.370417
# 2  number  verb  Catalan number_verb  Romance  ...        115.370417
# 3  number  verb  Catalan number_verb  Romance  ...        115.370417
# 4  number  verb  Catalan number_verb  Romance  ...        115.370417
#
#    sentence_char_per_subword  sentence_fertility  sentence_subword_len  \
# 0                   3.048666            1.440921              37.82125
# 1                   3.048666            1.440921              37.82125
# 2                   3.048666            1.440921              37.82125
# 3                   3.048666            1.440921              37.82125
# 4                   3.048666            1.440921              37.82125
#
#    sentence_word_len  target_char_len  target_char_per_subword  \
# 0          26.379167         8.084167                 3.365326
# 1          26.379167         8.084167                 3.365326
# 2          26.379167         8.084167                 3.365326
# 3          26.379167         8.084167                 3.365326
# 4          26.379167         8.084167                 3.365326
#
#    target_fertility  target_subw_entropy           model2
# 0            2.5525             8.780692  mBERT-rand-char
# 1            2.5525             8.780692       mBERT-char
# 2            2.5525             8.780692  mBERT-rand-subw
# 3            2.5525             8.780692            mBERT
# 4            2.5525             8.780692  mBERT-rand-char
#
# [5 rows x 25 columns]

# %%
if set(baselines['model'].unique()) != set(models):
    raise ValueError(f"Models missing from data?\n{baselines['model'].unique()} vs. {models}")

# %%
set(models) - set(baselines['model'].unique())
baselines['model'].unique()
# Out:
# array(['mBERT-rand-char', 'mBERT-char', 'mBERT-rand-subw', 'mBERT'],
#       dtype=object)

# %%
b = baselines.groupby(['model', 'language', 'task'])[['dev_acc', 'test_acc']].mean()
b.name = 'test_acc'
b = b.reset_index()
means = b.groupby('model').mean().sort_values('test_acc')
means / means.loc['mBERT']
# Out:
#                   dev_acc  test_acc
# model
# mBERT-rand-char  0.472789  0.477755
# mBERT-rand-subw  0.475732  0.481801
# mBERT-char       0.925201  0.919989
# mBERT            1.000000  1.000000

# %%
d = b.pivot_table(index=['language', 'task'], columns='model', values='test_acc')
d
# Out:
# model                       mBERT  mBERT-char  mBERT-rand-char  \
# language  task
# Afrikaans number_noun    0.945000    0.908500         0.544000
# Albanian  case_noun      0.685000    0.642000         0.239500
#           case_propn     0.829000    0.810000         0.337000
#           definite_noun  0.905000    0.859000         0.551500
#           gender_noun    0.870000    0.847000         0.519000
# ...                           ...         ...              ...
# Ukrainian tense_verb     0.873134    0.763682         0.341791
# Urdu      case_noun      0.879500    0.844000         0.504000
#           case_propn     0.868500    0.884500         0.509000
#           gender_noun    0.770000    0.757500         0.547500
#           number_noun    0.927500    0.876500         0.570000
#
# model                    mBERT-rand-subw
# language  task
# Afrikaans number_noun           0.465000
# Albanian  case_noun             0.244000
#           case_propn            0.370500
#           definite_noun         0.488500
#           gender_noun           0.567500
# ...                                  ...
# Ukrainian tense_verb            0.405473
# Urdu      case_noun             0.508000
#           case_propn            0.522500
#           gender_noun           0.544000
#           number_noun           0.435000
#
# [319 rows x 4 columns]

# %%
b = baselines.groupby(['model', 'language', 'task'])[['dev_acc', 'test_acc']].mean()
b.name = 'test_acc'
b = b.reset_index()
b['pos'] = b['task'].apply(lambda t: t.split('_')[1])
#b = b[b.model.isin(keep_models)]

all_mean = b.groupby('model').mean().reset_index()
all_mean['pos'] = 'ALL'

b = b.groupby(['model', 'pos']).mean().reset_index()

b = pd.concat((b, all_mean))
b.pos = b.pos.str.upper()

pos_order = ['ALL', 'NOUN', 'PROPN', 'VERB', 'ADJ']

b.pos = pd.Categorical(b.pos, ordered=True, categories=pos_order)
b
# Out:
#               model    pos   dev_acc  test_acc
# 0             mBERT    ADJ  0.945713  0.927282
# 1             mBERT   NOUN  0.930852  0.914294
# 2             mBERT  PROPN  0.868738  0.831250
# 3             mBERT   VERB  0.946529  0.926104
# 4        mBERT-char    ADJ  0.866724  0.846983
# 5        mBERT-char   NOUN  0.845024  0.823738
# 6        mBERT-char  PROPN  0.751725  0.719800
# 7        mBERT-char   VERB  0.902884  0.877607
# 8   mBERT-rand-char    ADJ  0.467728  0.459618
# 9   mBERT-rand-char   NOUN  0.450939  0.445071
# 10  mBERT-rand-char  PROPN  0.390193  0.379913
# 11  mBERT-rand-char   VERB  0.430277  0.429067
# 12  mBERT-rand-subw    ADJ  0.456170  0.448991
# 13  mBERT-rand-subw   NOUN  0.448499  0.446832
# 14  mBERT-rand-subw  PROPN  0.381588  0.388571
# 15  mBERT-rand-subw   VERB  0.447664  0.441903
# 0             mBERT    ALL  0.936063  0.916129
# 1        mBERT-char    ALL  0.866047  0.842829
# 2   mBERT-rand-char    ALL  0.442560  0.437685
# 3   mBERT-rand-subw    ALL  0.445315  0.441392

# %%
majority = baselines.groupby(['pos', 'language', 'task'])['majority_baseline'].mean().groupby('pos').mean()
majority.loc['all'] = baselines.groupby(['language', 'task'])['majority_baseline'].mean().mean()
majority.index = majority.index.str.upper()
majority
# Out:
# pos
# ADJ      43.787395
# NOUN     42.314139
# PROPN    37.491294
# VERB     41.594590
# ALL      42.038970
# Name: majority_baseline, dtype: float64

# %% [markdown]
# ## Bar chart

# %%
ax1 = sns.barplot(x="pos", y="test_acc", hue="model", data=b)


model_order = ['mBERT'] + model_perturbations # + baseline_models
with sns.plotting_context('paper', font_scale=1.8):
    fig, ax = plt.subplots(1, figsize=(18, 8), facecolor='w')
    sns.barplot(x=b.pos, y=b.test_acc, hue=b.model, hue_order=model_order, 
                #palette='tab20',
                #ci=None,
                edgecolor='black', linewidth=.5, ax=ax)
    ax.set_ylim(35, 100)
    ax.set_xlabel("")
    ax.set_ylabel("Test accuracy")
    ax.grid(True)
    ax.legend(title="", loc='lower right', framealpha=0.7, fancybox=True)
    
    for pi, p in enumerate(pos_order):
        yval = majority.loc[p]
        ax.plot((pi-0.45, pi+0.45), (yval, yval), linestyle='dashed', linewidth=2, color='black')
        
    plt.tight_layout()
    fig.savefig(f"{figure_dir}/bar_bert_modeling_perturbations_by_pos.pdf", dpi=600)

# %%
model_order = ['mBERT'] + model_perturbations # + baseline_models
with sns.plotting_context('paper', font_scale=1.8):
    fig, ax = plt.subplots(1, figsize=(18, 8), facecolor='w')
    sns.barplot(x=b.pos, y=b.test_acc, hue=b.model, hue_order=model_order, 
                palette='tab20',
                ci=None,
                edgecolor='black', linewidth=.5, ax=ax)
    ax.set_ylim(35, 100)
    ax.set_xlabel("")
    ax.set_ylabel("Test accuracy")
    ax.grid(True)
    ax.legend(title="", loc='lower right', framealpha=0.7, fancybox=True)
    
    for pi, p in enumerate(pos_order):
        yval = majority.loc[p]
        ax.plot((pi-0.45, pi+0.45), (yval, yval), linestyle='dashed', linewidth=2, color='black')
        
    plt.tight_layout()
    fig.savefig(f"{figure_dir}/bar_bert_modeling_perturbations_by_pos.pdf", dpi=600)

# %% [markdown]
# # Data perturbations

# %%
models = ['mBERT'] + data_perturbations + baseline_models

baselines = exps[
    ((exps.model.isin(baseline_models)) & (exps.perturbation.isnull())) |
    ((exps.model=='mBERT') & (exps.perturbation.isnull())) |
    ((exps.model=='mBERT') & (exps.perturbation.isin(data_perturbations)))
]
baselines = baselines[baselines['probing_location_better']==True].copy()

# %%
baselines['model2'] = None

baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isnull()), 'model2'] = 'mBERT'
baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isin(data_perturbations)), 'model2'] = \
    baselines.loc[(baselines['model']=='mBERT') & (baselines['perturbation'].isin(data_perturbations)), 'perturbation']
baselines.loc[((baselines.model.isin(baseline_models)) & (baselines.perturbation.isnull())), 'model2'] = \
    baselines.loc[((baselines.model.isin(baseline_models)) & (baselines.perturbation.isnull())), 'model']

# %%
baselines['model'] = baselines['model2']

# %%
if set(baselines['model'].unique()) != set(models):
    raise ValueError(f"Models missing from data?\n{baselines['model'].unique()} vs. {models}")

# %%
b = baselines.groupby(['model', 'language', 'task'])[['dev_acc', 'test_acc']].mean()
b.name = 'test_acc'
b = b.reset_index()
b.groupby('model').mean().sort_values('test_acc')
# Out:
#                dev_acc   test_acc
# model
# TARG         78.661090  75.957545
# chLSTM-rand  80.659546  78.259955
# swLSTM       84.434625  81.827378
# fastText     88.473438  86.472826
# chLSTM       89.230357  86.838669
# permute      88.849875  86.905506
# B$_2$        90.020074  88.245007
# L$_2$        92.087224  90.217150
# R$_2$        92.604197  90.776296
# mBERT        93.677373  91.756736

# %%
bert = b[b.model=='mBERT']
bert[bert['test_acc']>=99]
sns.displot(bert['test_acc'])
(bert['test_acc']>=95).mean()
# Out:
# 0.4169278996865204

# %%
#d = b.pivot_table(index=['language', 'task'], columns='model', values='test_acc')

# %%
b = baselines.groupby(['model', 'language', 'task'])[['dev_acc', 'test_acc']].mean()
b.name = 'test_acc'
b = b.reset_index()
b['pos'] = b['task'].apply(lambda t: t.split('_')[1])

all_mean = b.groupby('model').mean().reset_index()
all_mean['pos'] = 'ALL'

b = b.groupby(['model', 'pos']).mean().reset_index()

b = pd.concat((b, all_mean))
b.pos = b.pos.str.upper()

pos_order = ['ALL', 'NOUN', 'PROPN', 'VERB', 'ADJ']

b.pos = pd.Categorical(b.pos, ordered=True, categories=pos_order)

# %% [markdown]
# ## Bar chart

# %%
tab20 = sns.color_palette('tab20')
palette = [tab20[0], tab20[10], tab20[11], tab20[18], tab20[19], tab20[14], tab20[15], tab20[7], tab20[8]]
model_order = ['mBERT'] + data_perturbations + baseline_models
with sns.plotting_context('paper', font_scale=1.8):
    fig, ax = plt.subplots(1, figsize=(18, 8), facecolor='w')
    sns.barplot(x=b.pos, y=b.test_acc, hue=b.model, hue_order=model_order, 
                palette='Paired',
                ci=None,
                edgecolor='black', linewidth=.5, ax=ax)
    ax.set_ylim(35, 100)
    ax.set_xlabel("")
    ax.set_ylabel("Test accuracy")
    ax.grid(True)
    ax.legend(title="", loc='lower right', framealpha=1, fancybox=True)
    
    for pi, p in enumerate(pos_order):
        yval = majority.loc[p]
        ax.plot((pi-0.45, pi+0.45), (yval, yval), linestyle='dashed', linewidth=2, color='black')
        
    plt.tight_layout()
    fig.savefig(f"{figure_dir}/bar_bert_data_perturbations_by_pos.pdf", dpi=600)

# %% [markdown]
# # Results
#
#
# ## Tokenization
#
# mBERT-char

# %%
df = exps[
    ((exps['perturbation']=='mBERT-char') |
    ((exps['model']=='mBERT') & (exps['perturbation'].isnull()))
    ) &
    (exps['probing_location_better'])
].groupby(['family', 'language', 'task', 'perturbation'], dropna=False).test_acc.mean()
df = df.reset_index()
df['perturbation'] = df['perturbation'].fillna('mBERT')
df = df.rename(columns={'perturbation': 'model'})
means = df.groupby('model').mean()
means.loc['mBERT'] - means.loc['mBERT-char']
# Out:
# test_acc    7.656328
# dtype: float64

# %%
d = df.groupby(['family', 'language', 'task', 'model']).test_acc.mean().unstack()
diff_col_name = 'mBERT - mBERT-char'
d[diff_col_name] = d['mBERT'] - d['mBERT-char']
d = d.reset_index()
d = d.merge(fertility, on=['language', 'task'])
d.corr().loc[diff_col_name].sort_values()
# Out:
# mBERT-char                  -0.816986
# mBERT                       -0.348300
# majority_baseline           -0.316790
# sentence_word_len           -0.031104
# target_fertility             0.012832
# sentence_subword_len         0.030565
# sentence_fertility           0.075387
# sentence_char_len            0.145515
# first_entropy                0.153466
# target_subw_entropy          0.153466
# sentence_char_per_subword    0.166873
# target_char_len              0.168313
# target_char_per_subword      0.170472
# last_entropy                 0.409735
# mBERT - mBERT-char           1.000000
# Name: mBERT - mBERT-char, dtype: float64

# %%
d.corr()[diff_col_name].sort_values()
# Out:
# mBERT-char                  -0.816986
# mBERT                       -0.348300
# majority_baseline           -0.316790
# sentence_word_len           -0.031104
# target_fertility             0.012832
# sentence_subword_len         0.030565
# sentence_fertility           0.075387
# sentence_char_len            0.145515
# first_entropy                0.153466
# target_subw_entropy          0.153466
# sentence_char_per_subword    0.166873
# target_char_len              0.168313
# target_char_per_subword      0.170472
# last_entropy                 0.409735
# mBERT - mBERT-char           1.000000
# Name: mBERT - mBERT-char, dtype: float64

# %%
d.groupby(['language']).mean().sort_values(diff_col_name)
# Out:
#                        mBERT  mBERT-char  mBERT - mBERT-char  first_entropy  \
# language
# Catalan            98.956250   96.438738            2.517512       9.033923
# Romanian           91.691915   89.068159            2.623756       8.778845
# Urdu               85.975000   83.250000            2.725000       7.258230
# Hebrew             88.659901   85.884236            2.775665       5.210270
# Spanish            96.814286   93.714286            3.100000       9.438418
# Albanian           84.935714   81.571429            3.364286       8.849349
# Bulgarian          95.165174   91.611488            3.553686       7.384679
# Afrikaans          94.750000   91.000000            3.750000       8.491142
# Estonian           95.650274   91.630942            4.019333       8.405924
# Latvian            92.164583   87.950093            4.214490       7.762363
# Italian            94.743750   90.062500            4.681250       9.206816
# Portuguese         93.412500   88.625000            4.787500       9.623760
# Danish             94.252786   88.814428            5.438358       9.015343
# Latin              83.058131   77.588270            5.469861       8.517293
# Norwegian_Bokmal   95.157996   89.675551            5.482445       9.132916
# Basque             90.933812   84.984051            5.949761       9.251560
# English            94.650000   88.666667            5.983333       9.949680
# Norwegian_Nynorsk  93.852452   87.675551            6.176901       9.113325
# Arabic             84.712189   78.258706            6.453483       4.840756
# Hindi              85.966667   79.333333            6.633333       6.131728
# Turkish            93.222889   86.393599            6.829291       8.003351
# French             97.366803   90.403493            6.963310       9.281080
# Swedish            95.293750   88.312500            6.981250       8.885169
# Persian            95.700000   88.500000            7.200000       7.758662
# Greek              92.740199   83.945771            8.794428       5.065700
# Lithuanian         91.140441   82.333333            8.807108       8.508566
# Hungarian          94.983333   86.166667            8.816667       8.368401
# Czech              90.432583   81.615783            8.816800       8.017675
# Slovak             93.588384   84.605514            8.982870       7.927872
# Croatian           94.063692   85.015117            9.048575       8.654073
# Polish             90.513684   80.980457            9.533227       8.082578
# Armenian           86.366667   76.166667           10.200000       6.006133
# Serbian            92.278731   81.483831           10.794900       8.709441
# Russian            92.015489   81.118715           10.896774       7.284512
# Dutch              89.888744   78.773632           11.115112       9.111267
# Finnish            92.751736   81.526442           11.225293       8.473488
# Slovenian          90.186776   78.453944           11.732832       8.368470
# Ukrainian          92.774029   79.150067           13.623962       7.606422
# German             84.383605   65.075984           19.307621       9.275402
#
#                    last_entropy  majority_baseline  sentence_char_len  \
# language
# Catalan                7.267638          46.525990         118.708903
# Romanian               7.041988          42.963930         103.485233
# Urdu                   7.218278          57.125000          92.870000
# Hebrew                 7.720722          42.857143          84.328887
# Spanish                7.544925          43.500000         118.021310
# Albanian               7.248655          46.214286          82.110910
# Bulgarian              6.994835          46.754184          81.783887
# Afrikaans              7.551915          50.000000         127.413750
# Estonian               6.373816          39.587159         105.092264
# Latvian                6.858597          41.979167         104.171765
# Italian                7.709986          44.062500         103.405677
# Portuguese             8.284773          50.000000         105.325833
# Danish                 7.690273          47.466667         101.121765
# Latin                  6.644732          37.414739          97.057128
# Norwegian_Bokmal       7.529300          48.738095          92.016585
# Basque                 6.519360          36.363636          95.593999
# English                8.196288          41.666667          92.557083
# Norwegian_Nynorsk      7.579599          50.162402          93.083797
# Arabic                 7.053352          41.666667         115.005922
# Hindi                  7.028118          52.083333          89.548958
# Turkish                7.005376          37.850340          83.458112
# French                 7.638870          46.002352         109.831328
# Swedish                7.363397          50.000000          95.974844
# Persian                7.052547          50.000000          97.512500
# Greek                  7.455397          43.333333         133.367202
# Lithuanian             7.272087          41.666667         114.690488
# Hungarian              8.010404          50.000000         131.030972
# Czech                  6.988773          41.826087         102.554745
# Slovak                 7.081780          42.027778          65.646313
# Croatian               7.493061          40.748845         119.349239
# Polish                 7.346033          41.502953          63.026586
# Armenian               6.786189          53.333333         105.366250
# Serbian                7.698012          39.262023         120.577659
# Russian                7.790580          36.498756         110.654280
# Dutch                  8.435668          45.833333          96.161597
# Finnish                7.186491          31.330109          99.034855
# Slovenian              7.251990          33.426617          98.704405
# Ukrainian              7.772338          37.407407          99.502414
# German                 8.245611          37.121212         115.308597
#
#                    sentence_char_per_subword  sentence_fertility  \
# language
# Catalan                             3.061730            1.446146
# Romanian                            2.522710            1.794445
# Urdu                                2.056270            1.762899
# Hebrew                              2.011605            2.045988
# Spanish                             3.425491            1.349437
# Albanian                            2.480596            1.799899
# Bulgarian                           2.479598            1.913988
# Afrikaans                           3.001271            1.731115
# Estonian                            2.615394            2.242909
# Latvian                             2.321007            2.250113
# Italian                             3.207008            1.539106
# Portuguese                          3.208072            1.419757
# Danish                              2.875451            1.628063
# Latin                               2.940591            1.872043
# Norwegian_Bokmal                    3.009191            1.593411
# Basque                              2.931479            1.994232
# English                             3.492530            1.255916
# Norwegian_Nynorsk                   2.905764            1.604691
# Arabic                              2.206958            2.074608
# Hindi                               2.064760            1.899500
# Turkish                             2.597130            2.184900
# French                              3.338107            1.387946
# Swedish                             2.937952            1.736106
# Persian                             2.457821            1.602922
# Greek                               2.073665            2.535742
# Lithuanian                          2.565127            2.249394
# Hungarian                           2.687919            2.096909
# Czech                               2.519214            1.985594
# Slovak                              2.341542            2.034882
# Croatian                            2.806735            1.826146
# Polish                              2.601575            2.001346
# Armenian                            1.997759            2.585157
# Serbian                             2.832435            1.805634
# Russian                             2.773176            1.915077
# Dutch                               3.234531            1.523513
# Finnish                             2.872513            2.340509
# Slovenian                           2.579684            1.868704
# Ukrainian                           2.464892            2.002919
# German                              3.666707            1.538342
#
#                    sentence_subword_len  sentence_word_len  target_char_len  \
# language
# Catalan                       38.779389          26.943788         8.305481
# Romanian                      40.804740          22.976610         7.801813
# Urdu                          45.386771          25.751979         5.355313
# Hebrew                        42.057364          20.666230         5.049803
# Spanish                       34.474286          25.807798         8.576012
# Albanian                      32.770953          18.374647         7.719866
# Bulgarian                     32.638369          17.226783         8.167693
# Afrikaans                     42.552500          24.793750        10.723333
# Estonian                      39.909093          17.900749         8.959328
# Latvian                       44.474617          19.760012         8.241769
# Italian                       32.587187          21.602292         8.331042
# Portuguese                    32.821562          23.434167         7.691146
# Danish                        35.029781          21.787867         8.642553
# Latin                         32.946573          17.847410         8.832208
# Norwegian_Bokmal              30.387890          19.378889         8.972370
# Basque                        32.529962          16.346280         9.609091
# English                       26.436667          21.493333         7.490833
# Norwegian_Nynorsk             31.882874          20.148497         8.633131
# Arabic                        52.300497          25.391368         5.674537
# Hindi                         43.835903          23.030972         6.261319
# Turkish                       31.378067          14.490879         8.995909
# French                        33.081844          24.051803         8.306303
# Swedish                       32.680260          19.222396         9.158333
# Persian                       39.707083          24.939167         6.277500
# Greek                         64.469501          25.639829         8.851562
# Lithuanian                    44.499632          20.153833         8.468357
# Hungarian                     48.722778          23.374861         9.653889
# Czech                         40.450899          20.632994         8.486475
# Slovak                        27.521120          13.497214         7.610209
# Croatian                      42.509419          23.393891         8.307310
# Polish                        23.849623          11.987933         8.442934
# Armenian                      52.284861          20.331944         8.064583
# Serbian                       42.701529          23.829634         8.198247
# Russian                       39.802451          21.065392         9.082178
# Dutch                         29.705100          19.643993         8.818718
# Finnish                       34.209589          14.747014        10.206649
# Slovenian                     38.457388          20.585573         8.048356
# Ukrainian                     40.165393          20.200836         8.167389
# German                        31.705889          20.876413         9.559998
#
#                    target_char_per_subword  target_fertility  \
# language
# Catalan                           3.542712          2.557184
# Romanian                          2.835670          2.997170
# Urdu                              2.007779          2.923542
# Hebrew                            1.970029          2.764939
# Spanish                           3.791639          2.495179
# Albanian                          2.858888          2.939421
# Bulgarian                         2.665630          3.280597
# Afrikaans                         3.508751          3.307917
# Estonian                          2.794038          3.308019
# Latvian                           2.470253          3.483512
# Italian                           3.605141          2.530469
# Portuguese                        3.753841          2.310625
# Danish                            3.285669          2.852383
# Latin                             3.351967          2.781919
# Norwegian_Bokmal                  3.352028          2.857320
# Basque                            3.116335          3.209204
# English                           4.304360          2.047500
# Norwegian_Nynorsk                 3.212432          2.850982
# Arabic                            2.029939          2.976211
# Hindi                             1.940172          3.609097
# Turkish                           2.791451          3.377136
# French                            3.832602          2.462008
# Swedish                           3.127904          3.118073
# Persian                           2.503780          2.710417
# Greek                             1.978625          4.849386
# Lithuanian                        2.819105          3.211584
# Hungarian                         2.870437          3.595972
# Czech                             2.664368          3.388170
# Slovak                            2.558973          3.124724
# Croatian                          3.028507          2.903376
# Polish                            2.869570          3.174165
# Armenian                          2.172268          4.056250
# Serbian                           3.202651          2.753341
# Russian                           2.734368          3.488064
# Dutch                             3.601000          2.702605
# Finnish                           3.013793          3.504437
# Slovenian                         2.823647          2.986835
# Ukrainian                         2.772846          3.191211
# German                            4.210700          2.608381
#
#                    target_subw_entropy
# language
# Catalan                       9.033923
# Romanian                      8.778845
# Urdu                          7.258230
# Hebrew                        5.210270
# Spanish                       9.438418
# Albanian                      8.849349
# Bulgarian                     7.384679
# Afrikaans                     8.491142
# Estonian                      8.405924
# Latvian                       7.762363
# Italian                       9.206816
# Portuguese                    9.623760
# Danish                        9.015343
# Latin                         8.517293
# Norwegian_Bokmal              9.132916
# Basque                        9.251560
# English                       9.949680
# Norwegian_Nynorsk             9.113325
# Arabic                        4.840756
# Hindi                         6.131728
# Turkish                       8.003351
# French                        9.281080
# Swedish                       8.885169
# Persian                       7.758662
# Greek                         5.065700
# Lithuanian                    8.508566
# Hungarian                     8.368401
# Czech                         8.017675
# Slovak                        7.927872
# Croatian                      8.654073
# Polish                        8.082578
# Armenian                      6.006133
# Serbian                       8.709441
# Russian                       7.284512
# Dutch                         9.111267
# Finnish                       8.473488
# Slovenian                     8.368470
# Ukrainian                     7.606422
# German                        9.275402

# %% [markdown]
# ### mBERT-rand-char vs mBERT-rand-subw

# %%
df = exps[
    (exps.model=='mBERT') &
    (exps.probing_location_better) &
    (exps.perturbation.isin(('mBERT-rand-char', 'mBERT-rand-subw')))
].groupby(['pos', 'language', 'task', 'perturbation'])['test_acc'].mean().unstack().reset_index()
diff_col_name = '(mBERT-rand-subw) - (mBERT-rand-char)'
df[diff_col_name] = df['mBERT-rand-subw'] - df['mBERT-rand-char']
sns.displot(data=df, x=diff_col_name, col='pos')

# %%
df.groupby('language')[diff_col_name].mean().sort_values()
# Out:
# language
# Hebrew              -16.437931
# Arabic              -12.917910
# Dutch               -11.613184
# English             -10.500000
# French              -10.499083
# Norwegian_Nynorsk    -9.708600
# Swedish              -5.437500
# Bulgarian            -5.434871
# Portuguese           -5.375000
# German               -4.405020
# Armenian             -4.333333
# Serbian              -3.575871
# Albanian             -3.500000
# Norwegian_Bokmal     -3.443852
# Polish               -0.772189
# Afrikaans            -0.500000
# Hindi                -0.250000
# Catalan               0.113861
# Italian               0.875000
# Urdu                  1.125000
# Estonian              1.709721
# Slovak                2.568042
# Ukrainian             2.994163
# Danish                3.001990
# Basque                3.245614
# Slovenian             3.611593
# Spanish               3.714286
# Czech                 4.470251
# Latvian               4.557836
# Russian               5.030019
# Romanian              5.347015
# Croatian              6.887569
# Latin                 7.176401
# Hungarian             7.333333
# Lithuanian            9.250000
# Turkish               9.955150
# Finnish              13.408979
# Persian              13.500000
# Greek                16.696020
# Name: (mBERT-rand-subw) - (mBERT-rand-char), dtype: float64

# %%
df.merge(fertility, on=['language', 'task']).corr()[diff_col_name].sort_values()
# Out:
# mBERT-rand-char                         -0.442597
# last_entropy                            -0.157692
# majority_baseline                       -0.120415
# target_char_per_subword                 -0.073155
# sentence_char_per_subword               -0.061243
# sentence_word_len                       -0.059639
# first_entropy                           -0.056894
# target_subw_entropy                     -0.056894
# sentence_char_len                        0.064897
# sentence_subword_len                     0.086750
# target_char_len                          0.185570
# sentence_fertility                       0.197477
# target_fertility                         0.225367
# mBERT-rand-subw                          0.409424
# (mBERT-rand-subw) - (mBERT-rand-char)    1.000000
# Name: (mBERT-rand-subw) - (mBERT-rand-char), dtype: float64

# %%
df = exps[
    (exps.model=='mBERT') &
    (exps.probing_location_better) &
    ((exps.perturbation=='mBERT-char') | (exps.perturbation.isnull()))
].copy()
df['perturbation'] = df['perturbation'].fillna('mBERT')
df = df.groupby(['pos', 'language', 'task', 'perturbation'])['test_acc'].mean().unstack().reset_index()
diff_col_name = '(mBERT) - (mBERT-char)'
df[diff_col_name] = df['mBERT'] - df['mBERT-char']
sns.displot(data=df, x=diff_col_name, col='pos')

# %%
df.groupby('language')[diff_col_name].mean().sort_values()
# Out:
# language
# Catalan               2.517512
# Romanian              2.623756
# Urdu                  2.725000
# Hebrew                2.775665
# Spanish               3.100000
# Albanian              3.364286
# Bulgarian             3.553686
# Afrikaans             3.750000
# Estonian              4.019333
# Latvian               4.214490
# Italian               4.681250
# Portuguese            4.787500
# Danish                5.438358
# Latin                 5.469861
# Norwegian_Bokmal      5.482445
# Basque                5.949761
# English               5.983333
# Norwegian_Nynorsk     6.176901
# Arabic                6.453483
# Hindi                 6.633333
# Turkish               6.829291
# French                6.963310
# Swedish               6.981250
# Persian               7.200000
# Greek                 8.794428
# Lithuanian            8.807108
# Hungarian             8.816667
# Czech                 8.816800
# Slovak                8.982870
# Croatian              9.048575
# Polish                9.533227
# Armenian             10.200000
# Serbian              10.794900
# Russian              10.896774
# Dutch                11.115112
# Finnish              11.225293
# Slovenian            11.732832
# Ukrainian            13.623962
# German               19.307621
# Name: (mBERT) - (mBERT-char), dtype: float64

# %%
df.merge(fertility, on=['language', 'task']).corr()[diff_col_name].sort_values()
# Out:
# mBERT-char                  -0.816986
# mBERT                       -0.348300
# majority_baseline           -0.316790
# sentence_word_len           -0.031104
# target_fertility             0.012832
# sentence_subword_len         0.030565
# sentence_fertility           0.075387
# sentence_char_len            0.145515
# first_entropy                0.153466
# target_subw_entropy          0.153466
# sentence_char_per_subword    0.166873
# target_char_len              0.168313
# target_char_per_subword      0.170472
# last_entropy                 0.409735
# (mBERT) - (mBERT-char)       1.000000
# Name: (mBERT) - (mBERT-char), dtype: float64

# %%
df = exps[
    (exps.model=='mBERT') &
    (exps.probing_location_better) &
    ((exps.perturbation.isin(('mBERT-char', 'mBERT-rand-subw', 'mBERT-rand-char'))) | (exps.perturbation.isnull()))
].copy()
df['perturbation'] = df['perturbation'].fillna('mBERT')
df = df.groupby(['pos', 'language', 'task', 'perturbation'])['test_acc'].mean().reset_index()
df = df[df['language'].isin(('Finnish', 'English', 'German', 'Ukrainian' ,'Slovenian',
                             'Estonian', 'Greek', 'Basque', 'Turkish'))]
df['language'] = df['language'].apply(lambda l: lang2code[l])

fig, ax = plt.subplots(1, figsize=(20, 4))
sns.barplot(x=df['language'], y=df['test_acc'], hue=df['perturbation'], ax=ax)
# Out:
# <AxesSubplot:xlabel='language', ylabel='test_acc'>

# %%
df = exps[
    (exps.model=='mBERT') &
    (exps.probing_location_better) &
    ((exps.perturbation.isin(('mBERT-char', 'mBERT-rand-subw', 'mBERT-rand-char'))) | (exps.perturbation.isnull()))
].copy()
df['perturbation'] = df['perturbation'].fillna('mBERT')
df = df.groupby(['pos', 'language', 'task', 'perturbation'])['test_acc'].mean().unstack().reset_index()
df['diff'] = (1-df['mBERT']) / (1-df['mBERT-char'])
df['rand diff'] = (1-df['mBERT-rand-subw']) / (1-df['mBERT-rand-char'])
df['language'] = df['language'].str.replace('_', ' ')
df['language'] = df['language'].str.replace('Nynorsk', 'N')
df = df.groupby('language').mean()
top_idx = [0, 1, 2, 3, 4, -5, -4, -3, -2, -1]
top1 = df.sort_values('diff').iloc[top_idx]
top2 = df.sort_values('rand diff').iloc[top_idx]

top1 = top1.reset_index()[['language', 'diff']]
top2 = top2.reset_index()[['language', 'rand diff']]
top = pd.concat((top2, top1), axis=1)
top = top.round(3)
lines = top.to_latex(index=False).split('\n')
lines.insert(-8, '\\midrule')
with open(f"{figure_dir}/table_tokenization_diff_minmax.tex", "w") as f:
    f.write("\n".join(lines))

# %%
df.loc[['Urdu', 'Catalan', 'Spanish']]
# Out:
# perturbation      mBERT  mBERT-char  mBERT-rand-char  mBERT-rand-subw  \
# language
# Urdu          85.975000   83.250000        53.750000        54.875000
# Catalan       98.956250   96.438738        78.901609        79.015470
# Spanish       96.814286   93.714286        49.928571        53.642857
#
# perturbation      diff  rand diff
# language
# Urdu          1.034222   1.045714
# Catalan       1.028333   1.013956
# Spanish       1.036084   1.104955

# %%
df['ratio'] = df['diff'] / df['rand diff']

# %%
df.sort_values('ratio')
# Out:
# perturbation          mBERT  mBERT-char  mBERT-rand-char  mBERT-rand-subw  \
# language
# Lithuanian        91.140441   82.333333        52.286765        61.536765
# Finnish           92.751736   81.526442        43.070679        56.479658
# Greek             92.740199   83.945771        55.499005        72.195025
# Turkish           93.222889   86.393599        48.463870        58.419020
# Russian           92.015489   81.118715        47.535045        52.565064
# Romanian          91.691915   89.068159        56.753980        62.100995
# Italian           94.743750   90.062500        61.687500        62.562500
# Czech             90.432583   81.615783        51.229969        55.700220
# Persian           95.700000   88.500000        69.000000        82.500000
# Latin             83.058131   77.588270        44.665024        51.841425
# Spanish           96.814286   93.714286        49.928571        53.642857
# Latvian           92.164583   87.950093        54.553949        59.111785
# Estonian          95.650274   91.630942        50.321182        52.030903
# Croatian          94.063692   85.015117        54.155318        61.042887
# Danish            94.252786   88.814428        49.964677        52.966667
# Hungarian         94.983333   86.166667        57.333333        64.666667
# Urdu              85.975000   83.250000        53.750000        54.875000
# Slovak            93.588384   84.605514        51.390352        53.958394
# Catalan           98.956250   96.438738        78.901609        79.015470
# Afrikaans         94.750000   91.000000        51.500000        51.000000
# Ukrainian         92.774029   79.150067        52.581390        55.575554
# Polish            90.513684   80.980457        54.147486        53.375297
# Armenian          86.366667   76.166667        65.833333        61.500000
# Hindi             85.966667   79.333333        56.666667        56.416667
# Norwegian Bokmal  95.157996   89.675551        67.062900        63.619048
# Slovenian         90.186776   78.453944        49.374250        52.985843
# Portuguese        93.412500   88.625000        74.125000        68.750000
# Bulgarian         95.165174   91.611488        65.628675        60.193804
# English           94.650000   88.666667        72.833333        62.333333
# Albanian          84.935714   81.571429        59.142857        55.642857
# Basque            90.933812   84.984051        39.487241        42.732855
# Swedish           95.293750   88.312500        73.375000        67.937500
# Norwegian N       93.852452   87.675551        64.774343        55.065743
# Serbian           92.278731   81.483831        59.026119        55.450249
# Arabic            84.712189   78.258706        60.973881        48.055970
# French            97.366803   90.403493        65.604342        55.105260
# Dutch             89.888744   78.773632        70.274876        58.661692
# German            84.383605   65.075984        49.095432        44.690412
# Hebrew            88.659901   85.884236        61.702463        45.264532
#
# perturbation          diff  rand diff     ratio
# language
# Lithuanian        1.109448   1.706740  0.650039
# Finnish           1.144003   1.437478  0.795840
# Greek             1.110917   1.323658  0.839278
# Turkish           1.087157   1.268296  0.857180
# Russian           1.152862   1.300952  0.886168
# Romanian          1.030540   1.149111  0.896815
# Italian           1.054296   1.172654  0.899068
# Czech             1.131592   1.255840  0.901063
# Persian           1.082286   1.198529  0.903011
# Latin             1.083336   1.186865  0.912770
# Spanish           1.036084   1.104955  0.937671
# Latvian           1.050708   1.107377  0.948826
# Estonian          1.045984   1.083828  0.965083
# Croatian          1.122336   1.156003  0.970877
# Danish            1.067754   1.099521  0.971108
# Hungarian         1.103644   1.134502  0.972801
# Urdu              1.034222   1.045714  0.989011
# Slovak            1.117970   1.114460  1.003150
# Catalan           1.028333   1.013956  1.014179
# Afrikaans         1.041667   0.990099  1.052083
# Ukrainian         1.193079   1.117577  1.067559
# Polish            1.134866   1.053436  1.077300
# Armenian          1.155970   1.062606  1.087864
# Hindi             1.088430   0.996709  1.092024
# Norwegian Bokmal  1.070555   0.972127  1.101250
# Slovenian         1.169060   1.050921  1.112414
# Portuguese        1.060894   0.945189  1.122414
# Bulgarian         1.045920   0.930431  1.124124
# English           1.075344   0.955712  1.125175
# Albanian          1.045950   0.929256  1.125578
# Basque            1.072236   0.945267  1.134321
# Swedish           1.086972   0.951851  1.141956
# Norwegian N       1.075616   0.888752  1.210254
# Serbian           1.142402   0.941903  1.212866
# Arabic            1.101761   0.904661  1.217871
# French            1.087277   0.867047  1.254000
# Dutch             1.148152   0.886020  1.295852
# German            1.344824   0.944255  1.424217
# Hebrew            1.034659   0.725153  1.426816

# %%
exps[(exps.language=='English')].task.unique()
# Out:
# array(['number_noun', 'tense_verb', 'verbform_verb'], dtype=object)

# %%
df.corr()['diff'].sort_values()
# Out:
# perturbation
# mBERT-char        -0.821160
# mBERT             -0.346001
# mBERT-rand-char   -0.257895
# mBERT-rand-subw   -0.243128
# rand diff          0.129330
# ratio              0.235394
# diff               1.000000
# Name: diff, dtype: float64
